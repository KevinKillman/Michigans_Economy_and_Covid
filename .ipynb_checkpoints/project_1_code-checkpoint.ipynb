# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
from pprint import pprint

# %%
url = 'https://api.covidtracking.com/v1/states/mi/daily.json'
response = (requests.get(url).json())
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
covid_df = pd.DataFrame(response)
covid_df.dropna(axis=1, how='all', inplace = True)
covid_df['grade'].value_counts()
# Out:
#     208
# Name: grade, dtype: int64

# %%
del covid_df['hospitalizedIncrease'],covid_df['hash'],covid_df['commercialScore'],covid_df['negativeRegularScore'],covid_df['negativeScore'],covid_df['positiveScore'],covid_df['score'],covid_df['grade']

# %%
covid_dates = [datetime.date(int(str(x)[0:4]), int(str(x)[5]), int(str(x)[6:8])) for x in covid_df['date']]
covid_df['datetimes']=covid_dates
covid_df.head()
# Out:
#        date state  positive   negative  pending  totalTestResults  \
# 0  20200924    MI    132337  3330487.0      NaN           3462824
# 1  20200923    MI    131259  3293848.0      NaN           3425107
# 2  20200922    MI    130357  3260521.0      NaN           3390878
# 3  20200921    MI    129662  3241005.0      NaN           3370667
# 4  20200920    MI    128087  3190382.0      NaN           3318469
#
#    hospitalizedCurrently  inIcuCurrently  onVentilatorCurrently  recovered  \
# 0                  558.0           139.0                   50.0    90216.0
# 1                  501.0           146.0                   58.0    90216.0
# 2                  501.0           146.0                   56.0    90216.0
# 3                  501.0           146.0                   64.0    90216.0
# 4                  557.0           150.0                   64.0    90216.0
#
#   dataQualityGrade     lastUpdateEt          dateModified  checkTimeEt  \
# 0               A+  9/24/2020 00:00  2020-09-24T00:00:00Z  09/23 20:00
# 1               A+  9/23/2020 00:00  2020-09-23T00:00:00Z  09/22 20:00
# 2               A+  9/22/2020 00:00  2020-09-22T00:00:00Z  09/21 20:00
# 3               A+  9/21/2020 00:00  2020-09-21T00:00:00Z  09/20 20:00
# 4               A+  9/19/2020 00:00  2020-09-19T00:00:00Z  09/18 20:00
#
#     death           dateChecked  totalTestsViral  positiveTestsViral  \
# 0  7019.0  2020-09-24T00:00:00Z        3498071.0            167584.0
# 1  7013.0  2020-09-23T00:00:00Z        3460290.0            166442.0
# 2  6997.0  2020-09-22T00:00:00Z        3425958.0            165437.0
# 3  6981.0  2020-09-21T00:00:00Z        3405774.0            164769.0
# 4  6969.0  2020-09-19T00:00:00Z        3353686.0            163304.0
#
#    negativeTestsViral  positiveCasesViral  deathConfirmed  deathProbable  \
# 0           3330487.0              119597          6700.0          319.0
# 1           3293848.0              118615          6692.0          321.0
# 2           3260521.0              117910          6680.0          317.0
# 3           3241005.0              117406          6665.0          316.0
# 4           3190382.0              115870          6653.0          316.0
#
#    totalTestsAntibody fips  positiveIncrease  negativeIncrease    total  \
# 0            288257.0   26              1078             36639  3462824
# 1            287162.0   26               902             33327  3425107
# 2            285455.0   26               695             19516  3390878
# 3            285076.0   26              1575             50623  3370667
# 4            283882.0   26                 0                 0  3318469
#
#   totalTestResultsSource  totalTestResultsIncrease   posNeg  deathIncrease  \
# 0                 posNeg                     37717  3462824              6
# 1                 posNeg                     34229  3425107             16
# 2                 posNeg                     20211  3390878             16
# 3                 posNeg                     52198  3370667             12
# 4                 posNeg                         0  3318469              0
#
#     datetimes
# 0  2020-09-24
# 1  2020-09-23
# 2  2020-09-22
# 3  2020-09-21
# 4  2020-09-20

# %%
plt.plot(covid_df['datetimes'], covid_df['positive'])
plt.title('Positive Covid Tests in MI, Mar - Sept')
plt.ylabel('Number of Positive Tests')
plt.xlabel('Month')
plt.show()

# %%
emp_comb_path = 'Resources/EconomicTracker/data/Employment Combined - State - Daily.csv'

emp_comb_df = pd.read_csv(emp_comb_path)
mi_emp_comb_df = emp_comb_df.loc[emp_comb_df['statefips']==26]
mi_emp_comb_df.head()
# Out:
#      year  month  day  statefips  emp_combined emp_combined_inclow  \
# 22   2020      1   15         26     -0.001230            -.000268
# 73   2020      1   16         26     -0.000679             .000682
# 124  2020      1   17         26     -0.000132              .00163
# 175  2020      1   18         26      0.000427              .00262
# 226  2020      1   19         26      0.000985              .00361
#
#     emp_combined_incmiddle  emp_combined_inchigh emp_combined_ss40  \
# 22                 -.00115              -0.00255          -.000196
# 73                -.000624              -0.00245          -.000276
# 124              -.0000949              -0.00235          -.000307
# 175                .000434              -0.00226          -.000312
# 226                .000963              -0.00216          -.000317
#
#     emp_combined_ss60 emp_combined_ss65 emp_combined_ss70
# 22            -.00234           .000193           -.00555
# 73             -.0022           .000653           -.00418
# 124           -.00203            .00112           -.00278
# 175           -.00186            .00164           -.00117
# 226           -.00169            .00215           .000433

# %%
mi_emp_comb_df.loc[:, 'emp_combined'] *= 100
mi_emp_comb_df.head().style.format({'emp_combined': '{0:,.5f}%'})
# Out:
# C:\Users\state\anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# <style  type="text/css" >
# </style><table id="T_a3d3e94a_febf_11ea_b6e5_40a3cce58b3d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >year</th>        <th class="col_heading level0 col1" >month</th>        <th class="col_heading level0 col2" >day</th>        <th class="col_heading level0 col3" >statefips</th>        <th class="col_heading level0 col4" >emp_combined</th>        <th class="col_heading level0 col5" >emp_combined_inclow</th>        <th class="col_heading level0 col6" >emp_combined_incmiddle</th>        <th class="col_heading level0 col7" >emp_combined_inchigh</th>        <th class="col_heading level0 col8" >emp_combined_ss40</th>        <th class="col_heading level0 col9" >emp_combined_ss60</th>        <th class="col_heading level0 col10" >emp_combined_ss65</th>        <th class="col_heading level0 col11" >emp_combined_ss70</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a3d3e94a_febf_11ea_b6e5_40a3cce58b3dlevel0_row0" class="row_heading level0 row0" >22</th>
#                         <td id="T_a3d3e94a_febf_11ea_b6e5_40a3cce58b3drow0_col0" class="data row0 col0" >2020</td>
#                         <td id="T_a3d3e94a_febf_11ea_b6e5_40a3cce58b3drow0_col1" class="data row0 col1" >1</td>
#                         <td id="T_a3d3e94a_febf_11ea_b6e5_40a3cce58b3drow0_col2" class="data row0 col2" >15</td>
#                         <td id="T_a3d3e94a_febf_11ea_b6e5_40a3cce58b3drow0_col3" class="data row0 col3" >26</td>
#                         <th id="T_a3d3e94a_febf_11ea_b6e5_40a3cce58b3dlevel0_row4" class="row_heading level0 row4" >226</th>
#                         <td id="T_a3d3e94a_febf_11ea_b6e5_40a3cce58b3drow4_col0" class="data row4 col0" >2020</td>
#                         <td id="T_a3d3e94a_febf_11ea_b6e5_40a3cce58b3drow4_col1" class="data row4 col1" >1</td>
#                         <td id="T_a3d3e94a_febf_11ea_b6e5_40a3cce58b3drow4_col2" class="data row4 col2" >19</td>
#                         <td id="T_a3d3e94a_febf_11ea_b6e5_40a3cce58b3drow4_col3" class="data row4 col3" >26</td>
#                         <td id="T_a3d3e94a_febf_11ea_b6e5_40a3cce58b3drow4_col4" class="data row4 col4" >0.09850%</td>
#                         <td id="T_a3d3e94a_febf_11ea_b6e5_40a3cce58b3drow4_col5" class="data

# %%
date = []
per_change = []
for index in mi_emp_comb_df.index:
    date.append(datetime.date(mi_emp_comb_df.loc[index, 'year'],mi_emp_comb_df.loc[index, 'month'],mi_emp_comb_df.loc[index, 'day']))
    per_change.append(mi_emp_comb_df.loc[index, 'emp_combined'])
mi_emp_comb_df['datetimes'] = date
mi_emp_comb_df.head()



#str(mi_emp_comb_df.loc[x,'year'])+ '0'+str(mi_emp_comb_df.loc[x,'month'])
# Out:
# C:\Users\state\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      year  month  day  statefips  emp_combined emp_combined_inclow  \
# 22   2020      1   15         26       -0.1230            -.000268
# 73   2020      1   16         26       -0.0679             .000682
# 124  2020      1   17         26       -0.0132              .00163
# 175  2020      1   18         26        0.0427              .00262
# 226  2020      1   19         26        0.0985              .00361
#
#     emp_combined_incmiddle  emp_combined_inchigh emp_combined_ss40  \
# 22                 -.00115              -0.00255          -.000196
# 73                -.000624              -0.00245          -.000276
# 124              -.0000949              -0.00235          -.000307
# 175                .000434              -0.00226          -.000312
# 226                .000963              -0.00216          -.000317
#
#     emp_combined_ss60 emp_combined_ss65 emp_combined_ss70   datetimes
# 22            -.00234           .000193           -.00555  2020-01-15
# 73             -.0022           .000653           -.00418  2020-01-16
# 124           -.00203            .00112           -.00278  2020-01-17
# 175           -.00186            .00164           -.00117  2020-01-18
# 226           -.00169            .00215           .000433  2020-01-19

# %%
x_values = date
y_values = per_change


plt.plot(x_values, y_values)
plt.xlabel('Months')
plt.ylabel('Percent Change')
plt.title('Percentage Change in Employment Levels Compared to January 4-31, 2020', color = 'red')
plt.show()

# %%
covid_emp_merge = pd.merge(covid_df, mi_emp_comb_df, on='datetimes', how = 'inner')

x_values = covid_emp_merge['positiveIncrease']
y_values = covid_emp_merge['emp_combined']
plt.scatter(y_values, x_values)
plt.show()
covid_emp_merge.head()
# Out:
#        date state  positive   negative  pending  totalTestResults  \
# 0  20200729    MI     88974  1704259.0      NaN           1793233
# 1  20200728    MI     87958  1639924.0      NaN           1727882
# 2  20200727    MI     87173  1613316.0      NaN           1700489
# 3  20200726    MI     86661  1584083.0      NaN           1670744
# 4  20200725    MI     85072  1529574.0      NaN           1614646
#
#    hospitalizedCurrently  inIcuCurrently  onVentilatorCurrently  recovered  \
# 0                  670.0           195.0                  135.0    57502.0
# 1                  670.0           195.0                  135.0    57502.0
# 2                  670.0           195.0                  113.0    57502.0
# 3                  680.0           210.0                  113.0    57502.0
# 4                  751.0           215.0                  113.0    55162.0
#
#   dataQualityGrade     lastUpdateEt          dateModified  checkTimeEt  \
# 0               A+  7/29/2020 00:00  2020-07-29T00:00:00Z  07/28 20:00
# 1               A+  7/28/2020 00:00  2020-07-28T00:00:00Z  07/27 20:00
# 2               A+  7/27/2020 00:00  2020-07-27T00:00:00Z  07/26 20:00
# 3               A+  7/26/2020 00:00  2020-07-26T00:00:00Z  07/25 20:00
# 4               A+  7/24/2020 00:00  2020-07-24T00:00:00Z  07/23 20:00
#
#     death           dateChecked  totalTestsViral  positiveTestsViral  \
# 0  6422.0  2020-07-29T00:00:00Z        1819805.0            115546.0
# 1  6421.0  2020-07-28T00:00:00Z        1751875.0            111951.0
# 2  6405.0  2020-07-27T00:00:00Z        1723892.0            110576.0
# 3  6400.0  2020-07-26T00:00:00Z        1693712.0            109629.0
# 4  6400.0  2020-07-24T00:00:00Z        1637017.0            107443.0
#
#    negativeTestsViral  positiveCasesViral  deathConfirmed  deathProbable  \
# 0           1704259.0               80172          6172.0          250.0
# 1           1639924.0               79176          6170.0          251.0
# 2           1613316.0               78507          6154.0          251.0
# 3           1584083.0               78019          6149.0          251.0
# 4           1529574.0               76541          6151.0          249.0
#
#    totalTestsAntibody fips  positiveIncrease  negativeIncrease    total  \
# 0            210763.0   26              1016             64335  1793233
# 1            209655.0   26               785             26608  1727882
# 2            208729.0   26               512             29233  1700489
# 3            207540.0   26              1589             54509  1670744
# 4            204810.0   26                 0                 0  1614646
#
#   totalTestResultsSource  totalTestResultsIncrease   posNeg  deathIncrease  \
# 0                 posNeg                     65351  1793233              1
# 1                 posNeg                     27393  1727882             16
# 2                 posNeg                     29745  1700489              5
# 3                 posNeg                     56098  1670744              0
# 4                 posNeg                         0  1614646              0
#
#     datetimes  year  month  day  statefips  emp_combined emp_combined_inclow  \
# 0  2020-07-29  2020      7   29         26         -6.34               -.179
# 1  2020-07-28  2020      7   28         26         -6.35               -.179
# 2  2020-07-27  2020      7   27         26         -6.35               -.179
# 3  2020-07-26  2020      7   26         26         -6.35               -.179
# 4  2020-07-25  2020      7   25         26         -6.36               -.179
#
#   emp_combined_incmiddle  emp_combined_inchigh emp_combined_ss40  \
# 0                  -.033                0.0128            -.0685
# 1                 -.0333                0.0134            -.0688
# 2                 -.0336                0.0139             -.069
# 3                  -.034                0.0144            -.0693
# 4                 -.0343                0.0149            -.0696
#
#   emp_combined_ss60 emp_combined_ss65 emp_combined_ss70
# 0            -.0537             -.107             -.098
# 1            -.0544             -.107            -.0988
# 2            -.0551             -.107            -.0997
# 3            -.0559             -.107             -.101
# 4            -.0566             -.106             -.101
